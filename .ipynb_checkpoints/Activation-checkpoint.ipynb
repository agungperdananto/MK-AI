# %% [markdown]
# ## Activation

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1,1, 100)

# %% [markdown]
# ### Identity

# %%
def identity(x):
    y = x
    return y

# %%
y = identity(x)
plt.plot(x, y)
plt.grid()

# %% [markdown]
# ### Binary Step

# %%
def binary_step(x):
    y=[]
    for i in range(len(x)):
        if(x[i]<0):
            y_ = 0
        elif (x[i]>=0):
            y_ = 1
        y.append(y_)
    return y

# %%
y = binary_step(x)
plt.plot(x,y)
plt.grid()

# %% [markdown]
# ### Sigmoid

# %%
def sigmoid(x):
    y = 1/(1+np.exp(-x))
    return y

# %%
y = sigmoid(x)
plt.plot(x,y)
plt.grid()

# %% [markdown]
# ### TanH

# %%
y = np.tanh(x)
plt.plot(x,y)
plt.grid()

# %% [markdown]
# ### arcTan

# %%
y = np.arctan(x)
plt.plot(x,y)
plt.grid()

# %%
def relu(x):
    y=[]
    for i in range(len(x)):
        if(x[i]<0):
            y_ = 0
        elif (x[i]>=0):
            y_ = x[i]
        y.append(y_)
    return y

# %%
y = relu(x)
plt.plot(x,y)
plt.grid()

# %% [markdown]
# ### Softmax

# %%
def softmax(x, t = 1.0):
    e = np.exp(np.array(x) / t)
    y = e / np.sum(e)
    return y

# %%
y = softmax(x)
plt.plot(x,y)
plt.grid()
